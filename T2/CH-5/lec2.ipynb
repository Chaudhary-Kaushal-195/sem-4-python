# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
df=pd.read_csv('PlayTennis.csv')
df
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no

# %%
from sklearn.tree import plot_tree
plot_tree(df,feature_names=x.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 from sklearn.tree import plot_tree
# ----> 2 plot_tree(df,feature_names=x.columns)
#
# NameError: name 'x' is not defined

# %%
from sklearn.tree import plot_tree
plot_tree(df,feature_names=x.columns,filled=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from sklearn.tree import plot_tree
# ----> 2 plot_tree(df,feature_names=x.columns,filled=True)
#
# NameError: name 'x' is not defined

# %% [markdown]
# ### Step 1: Count outcomes
#
# From your 14 rows:
#
# Yes = 9
# No = 5
# Step 2: Convert to probabilities
# p(yes)=9/14≈0.643
# p(no)=5/14≈0.357
# Step 3: Entropy formula
# H(S)=−∑p(x)log
# 2
# 	​
#
# p(x)
# H(S)=−(
# 14
# 9
# 	​
#
# log
# 2
# 	​
#
# 14
# 9
# 	​
#
# +
# 14
# 5
# 	​
#
# log
# 2
# 	​
#
# 14
# 5
# 	​
#
# )
# Step 4: Compute
# H(S)≈−(0.643⋅log
# 2
# 	​
#
# 0.643+0.357⋅log
# 2
# 	​
#
# 0.357)
# H(S)≈−(0.643⋅(−0.64)+0.357⋅(−1.485))
# H(S)≈0.940 bits
# ✅ Final Answer:
#
# Entropy ≈ 0.94 bits
#
# This indicates the dataset is somewhat mixed (not pure, not completely random), which is typical for this classic decision tree example.
#
# find for temp
#
# Now you want the entropy after splitting on temp (i.e., the conditional entropy H(S∣temp)).
#
# Step 1: Group by temp
# Hot (4 samples)
# yes = 2, no = 2
# H
# hot
# 	​
#
# =−(
# 4
# 2
# 	​
#
# log
# 2
# 	​
#
# 4
# 2
# 	​
#
# +
# 4
# 2
# 	​
#
# log
# 2
# 	​
#
# 4
# 2
# 	​
#
# )=1.0
# Mild (6 samples)
# yes = 4, no = 2
# H
# mild
# 	​
#
# =−(
# 6
# 4
# 	​
#
# log
# 2
# 	​
#
# 6
# 4
# 	​
#
# +
# 6
# 2
# 	​
#
# log
# 2
# 	​
#
# 6
# 2
# 	​
#
# )≈0.918
# Cool (4 samples)
# yes = 3, no = 1
# H
# cool
# 	​
#
# =−(
# 4
# 3
# 	​
#
# log
# 2
# 	​
#
# 4
# 3
# 	​
#
# +
# 4
# 1
# 	​
#
# log
# 2
# 	​
#
# 4
# 1
# 	​
#
# )≈0.811
# Step 2: Weighted entropy
# H(S∣temp)=
# 14
# 4
# 	​
#
# (1.0)+
# 14
# 6
# 	​
#
# (0.918)+
# 14
# 4
# 	​
#
# (0.811)
# H(S∣temp)≈0.286+0.393+0.232
# H(S∣temp)≈0.911
# ✅ Final Answer:
#
# Entropy after splitting on temp ≈ 0.911 bits
#
# (Extra insight)
#
# If you compare with original entropy (0.94):
#
# Information Gain=0.94−0.911≈0.029
#
# So temp is not a very strong splitter for this dataset.

# %%
x=df.drop('play',axis=1)
x=pd.get_dummies(x)
y=df['play']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
df=DecisionTreeClassifier(criterion='entropy',random_state=42)
df.fit(x_train,y_train)
y_pred=df.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#           no       1.00      1.00      1.00         1
#          yes       1.00      1.00      1.00         2
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3

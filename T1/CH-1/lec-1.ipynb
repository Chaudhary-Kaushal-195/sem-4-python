# %%
import pandas as pd
import numpy as np

ds = pd.Series([10,20,30,40])
print(ds)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
import numpy as np

ds = pd.Series([10,20,30,40],index=['v','h','A','B'])
print(ds)
# Out:
# v    10
# h    20
# A    30
# B    40
# dtype: int64

# %%
import pandas as pd
import numpy as np

ds = pd.Series([10,20,30,40],index=['v','h','A','B'],dtype='float')
print(ds)
print(ds.size)
print(ds.shape)
# Out:
# v    10.0
# h    20.0
# A    30.0
# B    40.0
# dtype: float64
# 4
# (4,)

# %%
import pandas as pd
import numpy as np

ds = pd.Series([10,20,30,40],index=['v','h','A','B'],dtype='float',name='VHA')
print(ds)
# Out:
# v    10.0
# h    20.0
# A    30.0
# B    40.0
# Name: VHA, dtype: float64

# %%
import pandas as pd
import numpy as np

ds = pd.Series({1:"one",2:"two",3:"three",4:"four"},name='VHA')
print(ds)
# Out:
# 1      one
# 2      two
# 3    three
# 4     four
# Name: VHA, dtype: object

# %%
import pandas as pd
import numpy as np

ds = pd.Series(np.array([0,10,20,30]),name='VHA')
print(ds)
# Out:
# 0     0
# 1    10
# 2    20
# 3    30
# Name: VHA, dtype: int64

# %%
import pandas as pd
import numpy as np

ds = pd.DataFrame([['v','h','a'],[10,20,30],[1,2,3]],index=['p','q','r'],columns=['a','b','c'])

print(ds)
print(ds.size)
print(ds.shape)
print(ds.ndim)
print(ds.T)
# Out:
#     a   b   c
# p   v   h   a
# q  10  20  30
# r   1   2   3
# 9
# (3, 3)
# 2
#    p   q  r
# a  v  10  1
# b  h  20  2
# c  a  30  3

# %%
import pandas as pd
import numpy as np

ds = pd.DataFrame([['v','h','a'],[10,20,30],[1,2,3]],index=['p','q','r'],columns=['a','b','c'])

ds
# Out:
#     a   b   c
# p   v   h   a
# q  10  20  30
# r   1   2   3

# %%
ds.iloc[2,1]
# Out:
# 2

# %%
ds.loc["q","c"]
# Out:
# 30

# %%
import pandas as pd
import numpy as np

ds = pd.DataFrame({'name':['v','h','a'],'mark':[10,12,14],'cgpa':[9.2,9.5,9.0]},index=['p','q','r'])

print(ds)
# Out:
#   name  mark  cgpa
# p    v    10   9.2
# q    h    12   9.5
# r    a    14   9.0

# %%
import pandas as pd
import numpy as np

ds = pd.DataFrame([{'name':'vishal','mark':10},{'name':'kaushal','mark':11},{'name':'VHA','mark':12}],index=['p','q','r'])

print(ds)
print(ds.index)
print(ds.columns)
# Out:
#       name  mark
# p   vishal    10
# q  kaushal    11
# r      VHA    12
# Index(['p', 'q', 'r'], dtype='object')
# Index(['name', 'mark'], dtype='object')

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('train.csv')
print(df)
print("---------------------------------------------------------------------------")
print(df.index)
print("---------------------------------------------------------------------------")
print(df.columns)
print("---------------------------------------------------------------------------")
print(df.size)
print("---------------------------------------------------------------------------")
print(df.shape)
print("---------------------------------------------------------------------------")
print(df.values)
print("---------------------------------------------------------------------------")
print(df.dtypes)
print("---------------------------------------------------------------------------")
print(df.ndim)
print("---------------------------------------------------------------------------")
print(df.T)
print("---------------------------------------------------------------------------")
df=df.set_index('Name')
print("---------------------------------------------------------------------------")
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=df.reset_index()
print("---------------------------------------------------------------------------")
print(df)
# Out:
# ---------------------------------------------------------------------------
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# ...

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'name':['v','h','a'],
                   'mark':[10,12,14],
                   'cgpa':[9.2,9.5,9.0]},
                   index=['p','q','r'])


print(df)
# Out:
#   name  mark  cgpa
# p    v    10   9.2
# q    h    12   9.5
# r    a    14   9.0

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'name':['v','h','a'],
                   'mark':[10,12,14],
                   'cgpa':[9.2,9.5,9.0]},
                   index=['p','q','r'],
                  columns=['name','mark','cqpa'])


print(df)
# Out:
#   name  mark cqpa
# p    v    10  NaN
# q    h    12  NaN
# r    a    14  NaN

# %%
import pandas as pd
import numpy as np

df1 = pd.DataFrame({'name':['v','h','a'],
                   'mark':[10,12,14],
                   'cgpa':[9.2,9.5,9.0]},
                   index=['p','q','r'],
                  columns=['name','mark','cgpa'])


df1.set_index('name')
# Out:
#       mark  cgpa
# name
# v       10   9.2
# h       12   9.5
# a       14   9.0

# %%
import pandas as pd
import numpy as np

df1 = pd.DataFrame({'name':['v','h','a'],
                   'mark':[10,12,14],
                   'cgpa':[9.2,9.5,9.0]},
                   index=['p','q','r'],
                  columns=['name','mark','cgpa'])


df1.set_index('name',drop=True)
# Out:
#       mark  cgpa
# name
# v       10   9.2
# h       12   9.5
# a       14   9.0

# %%
import pandas as pd
import numpy as np

df1 = pd.DataFrame({'name':['v','h','a'],
                   'mark':[10,12,14],
                   'cgpa':[9.2,9.5,9.0]},
                   index=['p','q','r'],
                  columns=['name','mark','cgpa'])


df1=df1.set_index('name',drop=False)
print(df1)
# Out:
#      name  mark  cgpa
# name
# v       v    10   9.2
# h       h    12   9.5
# a       a    14   9.0

# %%
df=pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df['Name'])
print("--------------------------------------------------------------------------")
type(df['Name'])
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object
# --------------------------------------------------------------------------
# pandas.core.series.Series

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[['Name','Pclass']]
# Out:
#                                                   Name  Pclass
# 0                              Braund, Mr. Owen Harris       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                               Heikkinen, Miss. Laina       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4                             Allen, Mr. William Henry       3
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas       2
# 887                       Graham, Miss. Margaret Edith       1
# 888           Johnston, Miss. Catherine Helen "Carrie"       3
# 889                              Behr, Mr. Karl Howell       1
# 890                                Dooley, Mr. Patrick       3
#
# [891 rows x 2 columns]

# %%
df=pd.read_csv('train.csv')
print(df)

print("--------------------------------------------------------------------------")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[2,2]
# Out:
# np.int64(3)

# %%
df.iloc[2]
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
df.iloc[2:3,:]
# Out:
#    PassengerId  Survived  Pclass                    Name     Sex   Age  SibSp  \
# 2            3         1       3  Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 2      0  STON/O2. 3101282  7.925   NaN        S

# %%
df.iloc[1:10,2:5]
# Out:
#    Pclass                                               Name     Sex
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2       3                             Heikkinen, Miss. Laina  female
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       3                           Allen, Mr. William Henry    male
# 5       3                                   Moran, Mr. James    male
# 6       1                            McCarthy, Mr. Timothy J    male
# 7       3                     Palsson, Master. Gosta Leonard    male
# 8       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9       2                Nasser, Mrs. Nicholas (Adele Achem)  female

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc['Cumings, Mrs. John Bradley (Florence Briggs Thayer)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df.loc['Cumings, Mrs. John Bradley (Florence Briggs Thayer)']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1432, in _LocIndexer._getitem_axis(self, key, axis)
#    1430 # fall thru to straight lookup
#    1431 self._validate_key(key, axis)
# -> 1432 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._get_label(self, label, axis)
#    1380 def _get_label(self, label, axis: AxisInt):
# ...

# %%
df.loc['Cumings, Mrs. John Bradley (Florence Briggs Thayer)':'Devaney, Miss. Margaret Delia','PassengerId':'Age']

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame([[10,40,70],[20,50,80],[30,60,90]],
                   index=['A','B','C'],
                  columns=['P','Q','R'])


print(df)

# %%
df.loc["B","Q"]

# %%
df.loc["B"]

# %%
df.loc[:,'R']

# %%
print(df)
df.loc["B","Q"]=100
print(df)

# %%
df['D']=7
print(df)

# %%
print(df)
df["D"]=df['P']*df['Q']
print(df)

# %%
df.loc['A':'C','P':'R']

# %%
import pandas as pd
import numpy as np

ds = pd.DataFrame([[['a','b','c'],['p','q','r'],['x','y','z']],[10,20,30],[1,2,3]],index=['p','q','r'],columns=['a','b','c'])

print(ds)
print(ds.size)
print(ds.shape)
print(ds.ndim)
# Out:
#            a          b          c
# p  [a, b, c]  [p, q, r]  [x, y, z]
# q         10         20         30
# r          1          2          3
# 9
# (3, 3)
# 2

# %%
import pandas as pd
import numpy as np

ds = pd.DataFrame(['a'])

print(ds)
print("----------------------------------------------------------------------------")
print(ds.size)
print(ds.shape)
print(ds.ndim)
# Out:
#    0
# 0  a
# ----------------------------------------------------------------------------
# 1
# (1, 1)
# 2

# %%
import pandas as pd
import numpy as np

ds = np.array([[[0,10,20,30]]])
print(ds)
print("----------------------------------------------------------------------------")
print(ds.size)
print(ds.shape)
print(ds.ndim)
# Out:
# [[[ 0 10 20 30]]]
# ----------------------------------------------------------------------------
# 4
# (1, 1, 4)
# 3

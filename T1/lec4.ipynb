# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\LJENG\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df1=pd.DataFrame({"A":[1,2],"B":[3,4]})
df2=pd.DataFrame({"A":[5,7],"B":[7,9]})

# %%
df1
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
df2
# Out:
#    A  B
# 0  5  7
# 1  7  9

# %%
pd.concat((df1,df2))
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  7  9

# %%
pd.concat((df1,df2),axis=0)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  7  9

# %%
pd.concat((df1,df2),axis=1)
# Out:
#    A  B  A  B
# 0  1  3  5  7
# 1  2  4  7  9

# %%
df1=pd.DataFrame({"A":[1,2],"B":[3,4]})
df2=pd.DataFrame({"C":[5,7],"B":[7,9]})

# %%
pd.concat((df1,df2))
# Out:
#      A  B    C
# 0  1.0  3  NaN
# 1  2.0  4  NaN
# 0  NaN  7  5.0
# 1  NaN  9  7.0

# %%
df1=pd.DataFrame({"A":[1,2],"B":[3,4]})
df2=pd.DataFrame({"C":[5,7],"D":[7,9]})

# %%
pd.concat((df1,df2))
# Out:
#      A    B    C    D
# 0  1.0  3.0  NaN  NaN
# 1  2.0  4.0  NaN  NaN
# 0  NaN  NaN  5.0  7.0
# 1  NaN  NaN  7.0  9.0

# %%
pd.concat((df1,df2),axis=1)
# Out:
#    A  B  C  D
# 0  1  3  5  7
# 1  2  4  7  9

# %%
pd.concat((df1,df2),axis=0)
# Out:
#      A    B    C    D
# 0  1.0  3.0  NaN  NaN
# 1  2.0  4.0  NaN  NaN
# 0  NaN  NaN  5.0  7.0
# 1  NaN  NaN  7.0  9.0

# %%
df1=pd.DataFrame({"A":[1,2],"B":[3,4]})
df2=pd.DataFrame({"A":[5,7,9],"B":[7,91,2]})

# %%
pd.concat((df1,df2))
# Out:
#    A   B
# 0  1   3
# 1  2   4
# 0  5   7
# 1  7  91
# 2  9   2

# %%
pd.concat((df1,df2),axis=1)
# Out:
#      A    B  A   B
# 0  1.0  3.0  5   7
# 1  2.0  4.0  7  91
# 2  NaN  NaN  9   2

# %%
df1=pd.DataFrame({"A":[1,2],"B":[3,4]})
df2=pd.DataFrame({"A":[5,7],"B":[7,9]})

# %%
pd.concat((df1,df2))
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  7  9

# %%
pd.concat((df1,df2),ignore_index=True)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  5  7
# 3  7  9

# %%
pd.concat((df1,df2),ignore_index=False,keys=["A1","B1"])
# Out:
#       A  B
# A1 0  1  3
#    1  2  4
# B1 0  5  7
#    1  7  9

# %%
df1=pd.DataFrame({"A":[1,2],"B":[3,4]})
df2=pd.DataFrame({"C":[5,7],"D":[7,9]})

# %%
pd.concat((df1,df2),ignore_index=False,keys=["A1","B1"])
# Out:
#         A    B    C    D
# A1 0  1.0  3.0  NaN  NaN
#    1  2.0  4.0  NaN  NaN
# B1 0  NaN  NaN  5.0  7.0
#    1  NaN  NaN  7.0  9.0

# %%
df1=pd.DataFrame({"A":[1,2],"B":[3,4]})
df2=pd.DataFrame({"C":[5,7],"B":[7,9]})

# %%
pd.concat((df1,df2),ignore_index=False,keys=["A1","B1"])
# Out:
#         A  B    C
# A1 0  1.0  3  NaN
#    1  2.0  4  NaN
# B1 0  NaN  7  5.0
#    1  NaN  9  7.0

# %%
pd.concat((df1,df2),join="inner")
# Out:
#    B
# 0  3
# 1  4
# 0  7
# 1  9

# %%
pd.concat((df1,df2),join="outer")
# Out:
#      A  B    C
# 0  1.0  3  NaN
# 1  2.0  4  NaN
# 0  NaN  7  5.0
# 1  NaN  9  7.0

# %%
pd.concat((df1,df2),join="outer",sort=True)
# Out:
#      A  B    C
# 0  1.0  3  NaN
# 1  2.0  4  NaN
# 0  NaN  7  5.0
# 1  NaN  9  7.0

# %%
df1=pd.DataFrame({"sub":["FSD","python","DM"],
                  "fac":["nas","vha","mss"],
                 "id":[1,2,4]})
df2=pd.DataFrame({"id":[1,2,3],"mark":[9,10,8]})

# %%
df1
# Out:
#       sub  fac  id
# 0     FSD  nas   1
# 1  python  vha   2
# 2      DM  mss   4

# %%
df2
# Out:
#    id  mark
# 0   1     9
# 1   2    10
# 2   3     8

# %%
pd.merge(df1,df2,on="id")
# Out:
#       sub  fac  id  mark
# 0     FSD  nas   1     9
# 1  python  vha   2    10

# %%
pd.merge(df1,df2,on="id",how="inner")
# Out:
#       sub  fac  id  mark
# 0     FSD  nas   1     9
# 1  python  vha   2    10

# %%
pd.merge(df1,df2,on="id",how="outer")
# Out:
#       sub  fac  id  mark
# 0     FSD  nas   1   9.0
# 1  python  vha   2  10.0
# 2      DM  mss   4   NaN
# 3     NaN  NaN   3   8.0

# %%
df1.merge(df2,on="id")
# Out:
#       sub  fac  id  mark
# 0     FSD  nas   1     9
# 1  python  vha   2    10

# %%
df1.merge(df2,on="id",how="left")
# Out:
#       sub  fac  id  mark
# 0     FSD  nas   1   9.0
# 1  python  vha   2  10.0
# 2      DM  mss   4   NaN

# %%
df1.merge(df2,on="id",how="right")
# Out:
#       sub  fac  id  mark
# 0     FSD  nas   1     9
# 1  python  vha   2    10
# 2     NaN  NaN   3     8

# %%
df1.merge(df2,how="cross")
# Out:
#       sub  fac  id_x  id_y  mark
# 0     FSD  nas     1     1     9
# 1     FSD  nas     1     2    10
# 2     FSD  nas     1     3     8
# 3  python  vha     2     1     9
# 4  python  vha     2     2    10
# 5  python  vha     2     3     8
# 6      DM  mss     4     1     9
# 7      DM  mss     4     2    10
# 8      DM  mss     4     3     8

# %%
df1=pd.DataFrame({"sub":["FSD","python","DM"],
                  "fac":["nas","vha","mss"],
                 "id_x":[1,2,4]})
df2=pd.DataFrame({"id_y":[1,2,3],"mark":[9,10,8],"fac":["nas","vha","mss"]})

# %%
df1.merge(df2,left_on="id_x",right_on="id_y")
# Out:
#       sub fac_x  id_x  id_y  mark fac_y
# 0     FSD   nas     1     1     9   nas
# 1  python   vha     2     2    10   vha

# %%
df1.merge(df2,left_index=True,right_index=True)
# Out:
#       sub fac_x  id_x  id_y  mark fac_y
# 0     FSD   nas     1     1     9   nas
# 1  python   vha     2     2    10   vha
# 2      DM   mss     4     3     8   mss

# %%
df1.merge(df2,left_on="id_x",right_on="id_y",suffixes=("_df1","_df2"))
# Out:
#       sub fac_df1  id_x  id_y  mark fac_df2
# 0     FSD     nas     1     1     9     nas
# 1  python     vha     2     2    10     vha

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("auto-mpg.csv")

# %%
import seaborn as sns

# %%
sns.boxplot(df.acceleration)
# Out:
# <Axes: ylabel='acceleration'>

# %%
sns.boxplot(y="acceleration",hue="cylinders",data=df)
# Out:
# <Axes: ylabel='acceleration'>

# %%
sns.boxplot(y="acceleration",hue="origin",data=df)
# Out:
# <Axes: ylabel='acceleration'>

# %%
# import like this
items_path = "items.csv"
q1_path = "quarter-1.csv"
q2_path = "quarter-2.csv"
q3_path = "quarter-3.csv"


q1= pd.read_csv(q1_path)
q2 = pd.read_csv(q2_path)
q3 = pd.read_csv(q3_path)

items = pd.read_csv(items_path)

# %%
pd.concat((q1,q2,q3))
# Out:
#      order_id quantity item_id choice_description_id item_price
# 0           1        1       1                     1     $3.39
# 1           1        1       2                     2     $3.39
# 2           2        2       4                     3    $16.98
# 3           4        1       7                     6     $9.25
# 4           6        1       9                     8     $8.75
# ...       ...      ...     ...                   ...        ...
# 2342     1829        1      23                    92    $11.25
# 2343     1830        1      23                  1043    $11.25
# 2344     1832        1      10                   116     $8.75
# 2345     1832        1       8                     0     $4.45
# 2346     1834        1      20                   515    $11.25
#
# [4622 rows x 5 columns]

# %%
df=pd.concat((q1,q2,q3),keys=["Q1","Q2","Q3"])

# %%
df=df.reset_index()

# %%
df
# Out:
#      level_0  level_1 order_id quantity item_id choice_description_id  \
# 0         Q1        0        1        1       1                     1
# 1         Q1        1        1        1       2                     2
# 2         Q1        2        2        2       4                     3
# 3         Q1        3        4        1       7                     6
# 4         Q1        4        6        1       9                     8
# ...      ...      ...      ...      ...     ...                   ...
# 4617      Q2     2342     1829        1      23                    92
# 4618      Q2     2343     1830        1      23                  1043
# 4619      Q2     2344     1832        1      10                   116
# 4620      Q2     2345     1832        1       8                     0
# 4621      Q2     2346     1834        1      20                   515
#
#      item_price
# 0        $3.39
# 1        $3.39
# 2       $16.98
# 3        $9.25
# 4        $8.75
# ...         ...
# 4617    $11.25
# 4618    $11.25
# 4619     $8.75
# 4620     $4.45
# 4621    $11.25
#
# [4622 rows x 7 columns]

# %%
items
# Out:
#     item_id                              item_name
# 0         0           Chips and Fresh Tomato Salsa
# 1         1                                   Izze
# 2         2                       Nantucket Nectar
# 3         3  Chips and Tomatillo-Green Chili Salsa
# 4         4                           Chicken Bowl
# 5         5                          Side of Chips
# 6         6                          Steak Burrito
# 7         7                       Steak Soft Tacos
# 8         8                    Chips and Guacamole
# 9         9                   Chicken Crispy Tacos
# 10       10                     Chicken Soft Tacos
# 11       11                        Chicken Burrito
# 12       12                            Canned Soda
# 13       13                       Barbacoa Burrito
# 14       14                       Carnitas Burrito
# 15       15                          Carnitas Bowl
# 16       16                          Bottled Water
# 17       17  Chips and Tomatillo Green Chili Salsa
# 18       18                          Barbacoa Bowl
# 19       19                                  Chips
# 20       20                     Chicken Salad Bowl
# 21       21                             Steak Bowl
# 22       22                    Barbacoa Soft Tacos
# 23       23                         Veggie Burrito
# 24       24                            Veggie Bowl
# 25       25                     Steak Crispy Tacos
# 26       26    Chips and Tomatillo Red Chili Salsa
# 27       27                  Barbacoa Crispy Tacos
# 28       28                      Veggie Salad Bowl
# 29       29     Chips and Roasted Chili-Corn Salsa
# 30       30     Chips and Roasted Chili Corn Salsa
# 31       31                    Carnitas Soft Tacos
# 32       32                          Chicken Salad
# 33       33                      Canned Soft Drink
# 34       34                       Steak Salad Bowl
# 35       35                      6 Pack Soft Drink
# 36       36    Chips and Tomatillo-Red Chili Salsa
# 37       37                                   Bowl
# 38       38                                Burrito
# 39       39                           Crispy Tacos
# 40       40                  Carnitas Crispy Tacos
# 41       41                            Steak Salad
# 42       42      Chips and Mild Fresh Tomato Salsa
# 43       43                      Veggie Soft Tacos
# 44       44                    Carnitas Salad Bowl
# 45       45                    Barbacoa Salad Bowl
# 46       46                                  Salad
# 47       47                    Veggie Crispy Tacos
# 48       48                           Veggie Salad
# 49       49                         Carnitas Salad

# %%
df=df.merge(items,on="item_id")

# %%
df
# Out:
#      level_0  level_1 order_id quantity item_id choice_description_id  \
# 0         Q1        0        1        1       1                     1
# 1         Q1       10       12        1       1                    18
# 2         Q1       25       21        1       1                    33
# 3         Q1       34       30        1       1                    33
# 4         Q1      179      155        1       1                    33
# ...      ...      ...      ...      ...     ...                   ...
# 4617      Q2     1411     1094        1      48                   755
# 4618      Q2     1528     1192        1      48                   149
# 4619      Q2     1605     1263        1      48                   306
# 4620      Q2     1745     1395        1      48                   755
# 4621      Q2      826      668        1      47                   217
#
#      item_price            item_name
# 0        $3.39                  Izze
# 1        $3.39                  Izze
# 2        $3.39                  Izze
# 3        $3.39                  Izze
# 4        $3.39                  Izze
# ...         ...                  ...
# 4617     $8.49          Veggie Salad
# 4618     $8.49          Veggie Salad
# 4619     $8.49          Veggie Salad
# 4620     $8.49          Veggie Salad
# 4621     $8.49   Veggie Crispy Tacos
#
# [4622 rows x 8 columns]

# %%
df["quantity"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4617    1
# 4618    1
# 4619    1
# 4620    1
# 4621    1
# Name: quantity, Length: 4622, dtype: object

# %%
df.groupby(["level_0","item_name"],as_index=False)["quantity"].sum()
# Out:
#    level_0              item_name quantity
# 0       Q1      6 Pack Soft Drink       31
# 1       Q1          Barbacoa Bowl       34
# 2       Q1       Barbacoa Burrito       48
# 3       Q1  Barbacoa Crispy Tacos        6
# 4       Q1    Barbacoa Salad Bowl        5
# ..     ...                    ...      ...
# 90      Q2         Veggie Burrito       45
# 91      Q2    Veggie Crispy Tacos        1
# 92      Q2           Veggie Salad        5
# 93      Q2      Veggie Salad Bowl       10
# 94      Q2      Veggie Soft Tacos        6
#
# [95 rows x 3 columns]

# %%
df.groupby(["level_0","item_name"],as_index=False)["quantity"].sum().sort_values("quantity",ascending=False).drop_duplicates(subset=["level_0"])
# Out:
#    level_0     item_name quantity
# 65      Q2  Chicken Bowl      394
# 17      Q1  Chicken Bowl      367

# %%
df["price"]=df["item_price"].apply(lambda x: float(x[1:]))

# %%
df.price
# Out:
# 0       3.39
# 1       3.39
# 2       3.39
# 3       3.39
# 4       3.39
#         ...
# 4617    8.49
# 4618    8.49
# 4619    8.49
# 4620    8.49
# 4621    8.49
# Name: price, Length: 4622, dtype: float64

# %%
df["totalprice"]=df["quantity"]*df["price"]

# %%
df.totalprice
# Out:
# 0       3.39
# 1       3.39
# 2       3.39
# 3       3.39
# 4       3.39
#         ...
# 4617    8.49
# 4618    8.49
# 4619    8.49
# 4620    8.49
# 4621    8.49
# Name: totalprice, Length: 4622, dtype: object

# %%
df.groupby(["level_0","item_name"],as_index=False)["totalprice"].sum().sort_values("totalprice",ascending=False).drop_duplicates(subset=["level_0"])
# Out:
#    level_0     item_name totalprice
# 65      Q2  Chicken Bowl    4192.25
# 17      Q1  Chicken Bowl    3852.38

# %%
df.columns
# Out:
# Index(['level_0', 'level_1', 'order_id', 'quantity', 'item_id',
#        'choice_description_id', 'item_price', 'item_name', 'price',
#        'totalprice'],
#       dtype='object')

# %%
x=df.groupby(["level_0","order_id"])

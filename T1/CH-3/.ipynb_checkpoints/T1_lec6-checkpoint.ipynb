# %% [markdown]
# ## Heatmap

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data)
plt.show()
# Out:
# The data to be plotted:
#
# [[77 68 85 37  3 18 98  1 80 59]
#  [31 72 86 41 38 39 33 99 55 32]
#  [40 11 90 96 66 96 73 64 25 25]
#  [13 40 37 46 36  2 67 95 25 66]
#  [51 81 60 72 94 28 81 80 84 25]
#  [45  3 11 44 32 23 16 45 61 35]
#  [66 35 97 21 92 42 42 63 36 27]
#  [42 75 66 72 24 55 67 71 62  6]
#  [52  1 92 40 28 37 39 90 22 47]
#  [10 83 32 37 87 97 97  7  1 98]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,annot=True)
plt.show()
# Out:
# The data to be plotted:
#
# [[32 44 11 60 98 23 95 49 16 19]
#  [96 53 92 87  9 18 18 74 43 17]
#  [39 74 90 24 26 49 84 34 99 74]
#  [54 70 59 65 26  2 32 78 97 57]
#  [47  3 89 13 59 53 78 99 90 10]
#  [42 84  7 74 74 77 57 61 59 18]
#  [50 15 76 43 78 67 56 18 14 70]
#  [ 3 65 65  3 47 83 60 87 19 86]
#  [41 24 48 90 48 90 93 32  6 13]
#  [59 45 10 92 94 58 33 68 21 53]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,vmin=30,vmax=70,annot=True)
plt.show()
# Out:
# The data to be plotted:
#
# [[96 32 52 22 69  9 58 39 90 67]
#  [34 75 96 31  4 40 60 28  3 44]
#  [65 92 43 46 65 83 42 42 36 33]
#  [27 62 14 73 18 60 49 76 15 31]
#  [34 65 16 42  6 85 33  6 94 36]
#  [86 63 75 78 66 17 54 56 28 76]
#  [43 65 42 82 33 38 45 86 98 87]
#  [35 50  7 79 74 97 12 77 20 28]
#  [ 4 49 46 61 50 93 22 39 87  3]
#  [30 21 83 13 28  3 30 67  8 95]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,cmap="viridis")
plt.show()
# Out:
# The data to be plotted:
#
# [[87 23 89  1 44 38 50 74 74  7]
#  [77 19 80 91 83 45 17 51 88 16]
#  [63 59 68 78 92 62 71 43 67 13]
#  [42 37  1 38 65 63 29 33 77 75]
#  [81 71  4 26 62 92 37 83  3 18]
#  [16 18 40 15  9 91 62 94  5 79]
#  [21 82 65 63 42 17 84 15  4 58]
#  [65 84 95 46 59 39 44 11 90 19]
#  [85 80  8 85 13 14 72  3 47 58]
#  [87 88 39 68 32 69 16 80 82 64]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,annot=True,cmap="viridis",linewidths=1,linecolor='black',cbar=False,xticklabels=False,yticklabels=False)
plt.show()
# Out:
# The data to be plotted:
#
# [[ 2 30  7 33 86 13 12 99 70  1]
#  [44 10 69 55 38 75 77 63 76 10]
#  [99 93  3 50 61 69  7 11  3  9]
#  [20  9 76  7 99 41 82 71 63  4]
#  [70  1 35 54  1 69 58 92 11 48]
#  [ 9  1 12 45 82 95 59 74 50 17]
#  [30 32 53 55 74 11  4 36 11 99]
#  [13 30 84 64 19 97 14 63 84 28]
#  [57 14 33  2 95 38 50 36  4 91]
#  [79 39 16 96 79 53 38 22 81 25]]

# %%
import pandas as pd
df=pd.DataFrame(np.random.random((5,5)),columns=["a","b","c","d","e"])
print(df)
p1=sns.heatmap(df)
# Out:
#           a         b         c         d         e
# 0  0.689842  0.209103  0.887796  0.095267  0.481256
# 1  0.322190  0.581192  0.009689  0.333110  0.698275
# 2  0.234292  0.552062  0.678774  0.977749  0.563598
# 3  0.498933  0.127894  0.425435  0.395445  0.676701
# 4  0.231528  0.361798  0.312287  0.153115  0.669301

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
data=np.random.randint(low=1,high=100,size=(3,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,vmin=10,vmax=70,annot=True,cmap="Pastel1",linecolor='black',linewidth=2)
plt.show()
# Out:
# The data to be plotted:
#
# [[42 52 20 15 17 29 76 39 29 94]
#  [ 3  9 88 62 96 21 60 29 63 12]
#  [65  1 86 41 48 65 80 57  7 28]]

# %% [markdown]
# ## BoxPlot

# %%
df=pd.read_csv("auto-mpg.csv")
sns.boxplot(y=df['mpg'])
plt.show()

# %%
df=pd.read_csv("auto-mpg.csv")
sns.boxplot(y=df['acceleration'])
plt.show()

# %%
df=sns.load_dataset("tips")
sns.boxplot(x="day",y="total_bill",hue="smoker",data=df)
plt.show()
# Out:
# Running cells with 'Python 3.14.2' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/ayush/AppData/Local/Python/pythoncore-3.14-64/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
df=sns.load_dataset("tips")
sns.boxplot(x="day",y="tip",data=df)
plt.show()

# %% [markdown]
# ## ScatterPlot

# %%
df=pd.read_csv("auto-mpg.csv")
df["horsepower"]=pd.to_numeric(df["horsepower"],errors="coerce")
df=df.dropna(subset=["horsepower"])
plt.figure(figsize=(10,6))
sns.scatterplot(
    data=df,
    x="horsepower",
    y="mpg",
    hue="origin",
    style="origin",
    size="weight",
    palette="Set1"
)
plt.show()

# %%
df=pd.read_csv("auto-mpg.csv")
df["horsepower"]=pd.to_numeric(df["horsepower"],errors="coerce")
df=df.dropna(subset=["horsepower"])
plt.figure(figsize=(10,6))
sns.scatterplot(
    data=df,
    x="horsepower",
    y="mpg",
)
plt.show()

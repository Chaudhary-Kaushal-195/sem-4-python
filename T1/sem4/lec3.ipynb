# %%
import pandas as pd
import numpy as np

df=pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("auto-mpg.csv")

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin         car name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.horsepower.unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df[df["horsepower"]!="?"]["horsepower"].astype("int")
# Out:
# 0      130
# 1      165
# 2      150
# 3      150
# 4      140
#       ...
# 393     86
# 394     52
# 395     84
# 396     79
# 397     82
# Name: horsepower, Length: 392, dtype: int32

# %%
df[df["horsepower"]!="?"]["horsepower"].astype("int").mean()
# Out:
# 104.46938775510205

# %%
df["horsepower"]=df["horsepower"].replace("?",df[df["horsepower"]!="?"]["horsepower"].astype("int").mean())

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.horsepower.unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', 104.46938775510205, '100', '105', '175',
#        '153', '180', '110', '72', '86', '70', '76', '65', '69', '60',
#        '80', '54', '208', '155', '112', '92', '145', '137', '158', '167',
#        '94', '107', '230', '49', '75', '91', '122', '67', '83', '78',
#        '52', '61', '93', '148', '129', '96', '71', '98', '115', '53',
#        '81', '79', '120', '152', '102', '108', '68', '58', '149', '89',
#        '63', '48', '66', '139', '103', '125', '133', '138', '135', '142',
#        '77', '62', '132', '84', '64', '74', '116', '82'], dtype=object)

# %%
df["horsepower"]=df["horsepower"].astype("int")

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int32
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
df.isna()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 393  False      False         False       False   False         False
# 394  False      False         False       False   False         False
# 395  False      False         False       False   False         False
# 396  False      False         False       False   False         False
# 397  False      False         False       False   False         False
#
#      model year  origin  car name
# 0         False   False     False
# 1         False   False     False
# ...

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Length: 398, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.771543 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.839061  0.896017
# displacement -0.804203   0.950721      1.000000    0.893760  0.932824
# horsepower   -0.771543   0.839061      0.893760    1.000000  0.860676
# weight       -0.831741   0.896017      0.932824    0.860676  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.684376 -0.417457
# model year    0.579267  -0.348746     -0.370164   -0.411750 -0.306564
# origin        0.563450  -0.562543     -0.609409   -0.453613 -0.581024
#
#               acceleration  model year    origin
# mpg               0.420289    0.579267  0.563450
# cylinders        -0.505419   -0.348746 -0.562543
# displacement     -0.543684   -0.370164 -0.609409
# horsepower       -0.684376   -0.411750 -0.453613
# weight           -0.417457   -0.306564 -0.581024
# ...

# %%
pd.plotting.scatter_matrix(df,figsize=(20,20))
# Out:
# array([[<AxesSubplot:xlabel='mpg', ylabel='mpg'>,
#         <AxesSubplot:xlabel='cylinders', ylabel='mpg'>,
#         <AxesSubplot:xlabel='displacement', ylabel='mpg'>,
#         <AxesSubplot:xlabel='horsepower', ylabel='mpg'>,
#         <AxesSubplot:xlabel='weight', ylabel='mpg'>,
#         <AxesSubplot:xlabel='acceleration', ylabel='mpg'>,
#         <AxesSubplot:xlabel='model year', ylabel='mpg'>,
#         <AxesSubplot:xlabel='origin', ylabel='mpg'>],
#        [<AxesSubplot:xlabel='mpg', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='cylinders', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='displacement', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='horsepower', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='weight', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='acceleration', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='model year', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='origin', ylabel='cylinders'>],
# ...

# %%
df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       94
# weight          351
# acceleration     95
# model year       13
# origin            3
# car name        305
# dtype: int64

# %%
df.cylinders.value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
pd.plotting.parallel_coordinates(df,"cylinders",["acceleration","mpg","weight","horsepower"],color=["red","blue","green","yellow"])
# Out:
# <AxesSubplot:>

# %%
pd.plotting.parallel_coordinates(df,"origin",["acceleration","mpg","weight","horsepower"],color=["red","blue","green","yellow"])
# Out:
# <AxesSubplot:>

# %%
pd.crosstab(df["cylinders"],df["origin"],margins=True)
# Out:
# origin       1   2   3  All
# cylinders
# 3            0   0   4    4
# 4           72  63  69  204
# 5            0   3   0    3
# 6           74   4   6   84
# 8          103   0   0  103
# All        249  70  79  398

# %%
df.sort_values("mpg")
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28    9.0          8         304.0         193    4732          18.5
# 25   10.0          8         360.0         215    4615          14.0
# 26   10.0          8         307.0         200    4376          15.0
# 103  11.0          8         400.0         150    4997          14.0
# 124  11.0          8         350.0         180    3664          11.0
# ..    ...        ...           ...         ...     ...           ...
# 326  43.4          4          90.0          48    2335          23.7
# 394  44.0          4          97.0          52    2130          24.6
# 325  44.3          4          90.0          48    2085          21.7
# 329  44.6          4          91.0          67    1850          13.8
# 322  46.6          4          86.0          65    2110          17.9
#
#      model year  origin              car name
# 28           70       1              hi 1200d
# ...

# %%
df.sort_values("mpg",ascending=False)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0          65    2110          17.9
# 329  44.6          4          91.0          67    1850          13.8
# 325  44.3          4          90.0          48    2085          21.7
# 394  44.0          4          97.0          52    2130          24.6
# 326  43.4          4          90.0          48    2335          23.7
# ..    ...        ...           ...         ...     ...           ...
# 103  11.0          8         400.0         150    4997          14.0
# 67   11.0          8         429.0         208    4633          11.0
# 25   10.0          8         360.0         215    4615          14.0
# 26   10.0          8         307.0         200    4376          15.0
# 28    9.0          8         304.0         193    4732          18.5
#
#      model year  origin              car name
# 322          80       3             mazda glc
# ...

# %%
df.sort_values(["mpg","displacement"],ascending=[False,True])
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0          65    2110          17.9
# 329  44.6          4          91.0          67    1850          13.8
# 325  44.3          4          90.0          48    2085          21.7
# 394  44.0          4          97.0          52    2130          24.6
# 326  43.4          4          90.0          48    2335          23.7
# ..    ...        ...           ...         ...     ...           ...
# 103  11.0          8         400.0         150    4997          14.0
# 67   11.0          8         429.0         208    4633          11.0
# 26   10.0          8         307.0         200    4376          15.0
# 25   10.0          8         360.0         215    4615          14.0
# 28    9.0          8         304.0         193    4732          18.5
#
#      model year  origin              car name
# 322          80       3             mazda glc
# ...

# %%
import seaborn as sns
sns.boxenplot(y=df["horsepower"])
# Out:
# <AxesSubplot:ylabel='horsepower'>

# %%
df.horsepower.describe()
# Out:
# count    398.000000
# mean     104.462312
# std       38.199230
# min       46.000000
# 25%       76.000000
# 50%       95.000000
# 75%      125.000000
# max      230.000000
# Name: horsepower, dtype: float64

# %%
Q1=df.horsepower.quantile(0.25)

# %%
Q3=df.horsepower.quantile(0.75)

# %%
Q3
# Out:
# 125.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 49.0

# %%
h1=Q3+1.5*IQR
l1=Q1-1.5*IQR
h1,l1
# Out:
# (198.5, 2.5)

# %%
wo=df[(df["horsepower"]>l1)&(df["horsepower"]<h1)]

# %%
sns.boxenplot(wo["horsepower"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='horsepower'>

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("auto-mpg.csv")

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df=df[df["horsepower"]!="?"]

# %%
df["horsepower"]=df["horsepower"].astype("int")
# Out:
# C:\Users\LJENG\AppData\Local\Temp\ipykernel_668\3409201512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["horsepower"]=df["horsepower"].astype("int")

# %%
df.corr(numeric_only=True)
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.777618     -0.805127 -0.832244      0.423329
# cylinders    -0.777618   1.000000      0.950823  0.897527     -0.504683
# displacement -0.805127   0.950823      1.000000  0.932994     -0.543800
# weight       -0.832244   0.897527      0.932994  1.000000     -0.416839
# acceleration  0.423329  -0.504683     -0.543800 -0.416839      1.000000
# model year    0.580541  -0.345647     -0.369855 -0.309120      0.290316
# origin        0.565209  -0.568932     -0.614535 -0.585005      0.212746
#
#               model year    origin
# mpg             0.580541  0.565209
# cylinders      -0.345647 -0.568932
# displacement   -0.369855 -0.614535
# weight         -0.309120 -0.585005
# acceleration    0.290316  0.212746
# model year      1.000000  0.181528
# origin          0.181528  1.000000

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
import seaborn as sns

sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,vmin=0)
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,vmax=0)
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,vmin=0,linewidths=5,linecolor="red")
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,vmin=0,linewidths=5,linecolor="red",cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df,x="horsepower",y="weight")
# Out:
# <Axes: xlabel='horsepower', ylabel='weight'>

# %%
sns.scatterplot(data=df,x="horsepower",y="weight",hue="cylinders")
# Out:
# <Axes: xlabel='horsepower', ylabel='weight'>

# %%
sns.scatterplot(data=df,x="horsepower",y="weight",hue="cylinders",style="cylinders")
# Out:
# <Axes: xlabel='horsepower', ylabel='weight'>

# %%
sns.scatterplot(data=df,x="horsepower",y="weight",hue="cylinders",style="cylinders",s=100)
# Out:
# <Axes: xlabel='horsepower', ylabel='weight'>

# %%
import plotly.express as px

# %%
x=[1,2,3,4,5]
y=[3,6,2,4,8]
px.scatter(x,y)

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("social_media_engagement.csv")

# %%
df
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     694
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# ..      ...        ...       ...               ...    ...       ...     ...
# 95       96  Instagram  carousel   7/12/2023 17:45     36       294     911
# 96       97    Twitter     video  10/27/2023 23:45    314       108     458
# 97       98    Twitter      text     8/5/2023 8:45    229       179      38
# 98       99  Instagram      poll  12/29/2023 12:15   5000       500     204
# 99      100  Instagram     image    6/6/2023 21:00   4483       357      25
#
#      post_day sentiment_score
# ...

# %%
df.isna().sum()
# Out:
# post_id            0
# platform           0
# post_type          0
# post_time          0
# likes              0
# comments           0
# shares             0
# post_day           0
# sentiment_score    0
# dtype: int64

# %%
df.head()
# Out:
#    post_id   platform post_type        post_time  likes  comments  shares  \
# 0        1   Facebook     image  8/17/2023 14:45   2121       474     628
# 1        2   Facebook  carousel   5/14/2023 0:45   3660       432     694
# 2        3  Instagram      poll  2/21/2023 16:15   4955       408     688
# 3        4    Twitter     image  11/16/2023 0:45   1183        90     187
# 4        5    Twitter     video   5/23/2023 0:30   3499       247     286
#
#    post_day sentiment_score
# 0  Thursday        positive
# 1    Sunday         neutral
# 2   Tuesday        negative
# 3  Thursday        negative
# 4   Tuesday        positive

# %%
df.nunique()
# Out:
# post_id            100
# platform             3
# post_type            5
# post_time           99
# likes               93
# comments            85
# shares              96
# post_day             7
# sentiment_score      3
# dtype: int64

# %%
df.platform.unique()
# Out:
# array(['Facebook', 'Instagram', 'Twitter'], dtype=object)

# %%
df.post_time.unique()
# Out:
# array(['8/17/2023 14:45', '5/14/2023 0:45', '2/21/2023 16:15',
#        '11/16/2023 0:45', '5/23/2023 0:30', '5/5/2023 20:00',
#        '2/26/2023 11:45', '10/28/2023 19:30', '5/2/2023 6:15',
#        '5/11/2023 11:00', '12/8/2023 2:15', '6/15/2023 3:15',
#        '11/11/2023 15:45', '9/30/2023 10:30', '1/9/2023 20:00',
#        '2/10/2023 13:00', '7/5/2023 5:15', '7/23/2023 5:45',
#        '11/20/2023 2:00', '2/2/2023 16:00', '1/30/2023 13:30',
#        '10/2/2023 12:15', '1/1/2023 20:00', '5/17/2023 0:15',
#        '10/5/2023 6:30', '10/6/2023 10:00', '3/1/2023 8:00',
#        '1/7/2023 10:30', '2/3/2023 0:30', '9/10/2023 13:45',
#        '7/1/2023 14:45', '9/27/2023 19:00', '2/9/2023 15:30',
#        '6/6/2023 19:30', '4/8/2023 19:15', '5/11/2023 0:30',
#        '5/2/2023 0:30', '1/1/2023 6:00', '8/4/2023 12:45',
#        '12/27/2023 11:30', '11/23/2023 2:00', '3/31/2023 16:00',
#        '7/6/2023 8:00', '12/1/2023 10:00', '5/16/2023 22:15',
# ...

# %%
df.sentiment_score.unique()
# Out:
# array(['positive', 'neutral', 'negative'], dtype=object)

# %%
df.groupby("platform")["likes"].sum()
# Out:
# platform
# Facebook    238181
# Name: likes, dtype: int64

# %%
df.likes
# Out:
# 0     2121
# 1     3660
# 2     4955
# 3     1183
# 4     3499
#       ...
# 95      36
# 96     314
# 97     229
# 98    5000
# 99    4483
# Name: likes, Length: 100, dtype: int64

# %%
df.groupby("platform")[["likes","comments","shares"]].sum()
# Out:
#             likes  comments  shares
# platform
# Facebook    86392      7965   15180
# Instagram  107994      8368   18906
# Twitter     43795      3933    7479

# %%
df.groupby("platform")[["likes"]].sum()
# Out:
#             likes
# platform
# Facebook    86392
# Instagram  107994
# Twitter     43795

# %%
x= df.groupby("platform")["likes"].sum().apply(lambda x: "good" if x>50000 else "verygood")

# %%
x
# Out:
# platform
# Facebook         good
# Instagram        good
# Twitter      verygood
# Name: likes, dtype: object

# %%
df.groupby("platform",sort=True).head()
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     694
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# 5         6  Instagram  carousel    5/5/2023 20:00    256       186     211
# 6         7  Instagram     image   2/26/2023 11:45   1982        30     906
# 7         8  Instagram      text  10/28/2023 19:30   1274        45     216
# 8         9   Facebook     video     5/2/2023 6:15    317       249     221
# 9        10    Twitter  carousel   5/11/2023 11:00   1878       225     438
# 10       11    Twitter      text    12/8/2023 2:15   1446        44      52
# ...

# %%
df.groupby("platform",sort=True).sample()
# Out:
#     post_id   platform post_type        post_time  likes  comments  shares  \
# 61       62   Facebook  carousel  1/27/2023 15:45   3742       227     849
# 55       56  Instagram     image  3/13/2023 23:15   3401       190     230
# 37       38    Twitter      poll    5/2/2023 0:30   2463       187     445
#
#    post_day sentiment_score
# 61   Friday        negative
# 55   Monday        negative
# 37  Tuesday        positive

# %%
df.groupby("platform",sort=True).describe()
# Out:
#           post_id                                                       likes  \
#             count       mean        std  min    25%   50%    75%    max count
# platform
# Facebook     32.0  51.531250  29.195652  1.0  28.75  53.0  76.25   94.0  32.0
# Instagram    36.0  57.472222  28.866675  3.0  38.75  60.5  79.75  100.0  36.0
# Twitter      32.0  41.625000  27.492814  4.0  18.75  39.5  56.00   98.0  32.0
#
#                         ... comments        shares                          \
#                   mean  ...      75%    max  count        mean         std
# platform                ...
# Facebook   2699.750000  ...   393.00  500.0   32.0  474.375000  299.739430
# Instagram  2999.833333  ...   339.00  500.0   36.0  525.166667  284.467472
# Twitter    1368.593750  ...   162.25  247.0   32.0  233.718750  156.508525
#
#
#             min     25%    50%     75%    max
# platform
# Facebook   16.0  283.00  408.5  728.75  993.0
# Instagram  25.0  226.50  573.5  758.00  956.0
# ...

# %%
df.groupby("platform").size()
# Out:
# platform
# Facebook     32
# Instagram    36
# Twitter      32
# dtype: int64

# %%
df.shape
# Out:
# (100, 9)

# %%
df.groupby("platform").groups
# Out:
# {'Facebook': [0, 1, 8, 12, 14, 19, 25, 27, 28, 29, 30, 35, 36, 38, 46, 47, 57, 61, 65, 66, 69, 71, 72, 74, 79, 80, 83, 84, 87, 90, 91, 93], 'Instagram': [2, 5, 6, 7, 16, 23, 26, 31, 34, 39, 41, 43, 45, 49, 53, 55, 56, 59, 60, 63, 64, 67, 70, 73, 75, 77, 78, 81, 82, 86, 89, 92, 94, 95, 98, 99], 'Twitter': [3, 4, 9, 10, 11, 13, 15, 17, 18, 20, 21, 22, 24, 32, 33, 37, 40, 42, 44, 48, 50, 51, 52, 54, 58, 62, 68, 76, 85, 88, 96, 97]}

# %%
for i,j in df.groupby("platform"):
    print(i,"name")
    print(j,"data")
# Out:
# Facebook name
#     post_id  platform post_type         post_time  likes  comments  shares  \
# 0         1  Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2  Facebook  carousel    5/14/2023 0:45   3660       432     694
# 8         9  Facebook     video     5/2/2023 6:15    317       249     221
# 12       13  Facebook  carousel  11/11/2023 15:45     45        78     375
# 14       15  Facebook  carousel    1/9/2023 20:00    889       314     262
# 19       20  Facebook     image    2/2/2023 16:00    455        86      79
# 25       26  Facebook  carousel    10/5/2023 6:30   1992        70     515
# 27       28  Facebook      poll     3/1/2023 8:00   2083       500     388
# 28       29  Facebook     image    1/7/2023 10:30    548       153     731
# 29       30  Facebook  carousel     2/3/2023 0:30   4594       216     739
# 30       31  Facebook      poll   9/10/2023 13:45   4795       449     978
# ...

# %%
df.groupby("platform").nth(0)
# Out:
#    post_id   platform post_type        post_time  likes  comments  shares  \
# 0        1   Facebook     image  8/17/2023 14:45   2121       474     628
# 2        3  Instagram      poll  2/21/2023 16:15   4955       408     688
# 3        4    Twitter     image  11/16/2023 0:45   1183        90     187
#
#    post_day sentiment_score
# 0  Thursday        positive
# 2   Tuesday        negative
# 3  Thursday        negative

# %%
df1=pd.read_csv("ipl-matches.csv")
df1
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df1.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df1.Team1.unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
df1[((df1["Team1"]=="Mumbai Indians")|(df1["Team2"]=="Mumbai Indians"))&(df1["WinningTeam"]=="Mumbai Indians")]
# Out:
#           ID         City        Date   Season MatchNumber  \
# 5    1304115       Mumbai  2022-05-21     2022          69
# 15   1304105       Mumbai  2022-05-12     2022          59
# 23   1304097       Mumbai  2022-05-06     2022          51
# 30   1304090  Navi Mumbai  2022-04-30     2022          44
# 79   1254088    Abu Dhabi  2021-10-08     2021          55
# ..       ...          ...         ...      ...         ...
# 912   336021       Mumbai  2008-05-16  2007/08          38
# 914   336018       Mumbai  2008-05-14  2007/08          36
# 923   336008       Mumbai  2008-05-07  2007/08          27
# 927   336004       Mumbai  2008-05-04  2007/08          23
# 934   335997      Kolkata  2008-04-29  2007/08          16
#
#                      Team1                  Team2  \
# 5           Delhi Capitals         Mumbai Indians
# 15     Chennai Super Kings         Mumbai Indians
# 23          Mumbai Indians         Gujarat Titans
# 30        Rajasthan Royals         Mumbai Indians
# ...

# %%
df1[((df1["Team1"]=="Mumbai Indians")|(df1["Team2"]=="Mumbai Indians"))&(df1["WinningTeam"]=="Mumbai Indians")].Player_of_Match.value_counts()
# Out:
# Player_of_Match
# RG Sharma          15
# KA Pollard         14
# SR Tendulkar        8
# JJ Bumrah           7
# AT Rayudu           7
# SL Malinga          6
# HH Pandya           6
# Harbhajan Singh     6
# SA Yadav            5
# KH Pandya           4
# DR Smith            4
# Q de Kock           3
# Ishan Kishan        3
# LMP Simmons         3
# TA Boult            3
# MG Johnson          2
# N Rana              2
# MEK Hussey          2
# CJ Anderson         2
# JP Duminy           2
# MJ McClenaghan      2
# SM Pollock          2
# ST Jayasuriya       2
# MM Patel            2
# YK Pathan           1
# R McLaren           1
# RE Levi             1
# CRD Fernando        1
# R Sharma            1
# DJ Bravo            1
# JEC Franklin        1
# PA Patel            1
# DW Steyn            1
# KD Karthik          1
# AP Tare             1
# DR Sams             1
# JC Buttler          1
# KV Sharma           1
# AS Joseph           1
# RD Chahar           1
# ...

# %%
sum(df1.SuperOver=="Y")
# Out:
# 14

# %%
sum(df1["TossWinner"]==df1["WinningTeam"])/df1.TossWinner.count()
# Out:
# np.float64(0.5147368421052632)

# %%
df[(df1["Venue"]=="Wankhede Stadium")&(df1["WinningTeam"]=="Mumbai Indians")].count()
# Out:
# C:\Users\LJENG\AppData\Local\Temp\ipykernel_668\3012651616.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# post_id            0
# platform           0
# post_type          0
# post_time          0
# likes              0
# comments           0
# shares             0
# post_day           0
# sentiment_score    0
# dtype: int64

# %%
(df1["WinningTeam"]=="Mumbai Indians").
# Out:
# np.int64(131)

# %%
df1
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

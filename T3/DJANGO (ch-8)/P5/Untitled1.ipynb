# %%
import requests

# %%
url="http://127.0.0.1:8000/api/"
res=requests.get(url)
print(res.status_code)
print(res.json())
# Out:
# 200
# {'project': 'REST API Project', 'created_by': 'Prof. Vishal Acharya', 'subject': 'Python Programming'}

# %%
url1="http://127.0.0.1:8000/api/players"
res1=requests.get(url1)
print(res1.status_code)
print(res1.json())
# Out:
# 200
# {'count': 6, 'next': 'http://127.0.0.1:8000/api/players/?page=2', 'previous': None, 'results': [{'id': 2, 'name': 'Virat Kohli', 'runs': 14000, 'innings': 300}, {'id': 3, 'name': 'Virat Kohli', 'runs': 14000, 'innings': 300}, {'id': 4, 'name': 'Virat Kohli', 'runs': 1200, 'innings': 275}, {'id': 5, 'name': 'koh', 'runs': 1200, 'innings': 275}, {'id': 6, 'name': 'ko', 'runs': 1200, 'innings': 275}]}

# %%
token="176f17530fdbb5308f3dbc1419100c53f4ecdaa8"

# %%
import requests
url="http://127.0.0.1:8000/api/players/"
headers ={
    "Authorization":"Token 176f17530fdbb5308f3dbc1419100c53f4ecdaa8"
}
response =requests.get(url,headers=headers)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'count': 6, 'next': 'http://127.0.0.1:8000/api/players/?page=2', 'previous': None, 'results': [{'id': 2, 'name': 'Virat Kohli', 'runs': 14000, 'innings': 300}, {'id': 3, 'name': 'Virat Kohli', 'runs': 14000, 'innings': 300}, {'id': 4, 'name': 'Virat Kohli', 'runs': 1200, 'innings': 275}, {'id': 5, 'name': 'koh', 'runs': 1200, 'innings': 275}, {'id': 6, 'name': 'ko', 'runs': 1200, 'innings': 275}]}
